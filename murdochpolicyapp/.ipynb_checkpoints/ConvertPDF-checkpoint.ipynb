# %%
#Import
import os as os
import glob
from io import StringIO
import numpy as np
import pandas as pd
import sys

#PDF Import
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser
from pdfminer.pdftypes import resolve1
from pdfminer.psparser import PSLiteral, PSKeyword
from pdfminer.utils import decode_text

#NLTK
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
#Preprocessing - Convert lower case
def convert_lower_case(data):
    return np.char.lower(data)

# %%
print(os.getcwd())

# %%
#Preprocessing - Remove Stop words
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    
    #Extend Stopwords
    sw_filename = os.get'/Users/pamelapham/Documents/Murdoch/ICT302/CoreProgram/stop_words.txt'
    policy_stop_words = []
    with open(sw_filename) as f:
      for line in f:
        policy_stop_words.extend(line.rstrip('\n').split(','))
    
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in policy_stop_words  and w not in stop_words and len(w) > 3: #remove also the word with length <= 2
            new_text = new_text + " " + w
    return new_text

# %%
#Preprocessing - Remove Punctuation
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
#Preprocessing - Remove Apostrophe
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
#Preprocessing - Stemming
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
#Preprocessing - convert numbers
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
#Preprocessing Data
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    data = stemming(data)
    data = remove_punctuation(data)
    data = convert_numbers(data)
    data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %%
def remove_empty_lines(filename):
    #Overwrite the file, removing empty lines and lines that contain only whitespace.
    with open(filename, 'r+') as f:
        lines = f.readlines()
        f.seek(0)
        f.writelines(line for line in lines if line.strip())
        f.truncate()

# %%
def pdf_to_txt(pdfFileName):
    output_string = StringIO()
    txtFileName = pdfFileName[0:pdfFileName.rindex('.')]+'.txt'
    print(txtFileName)
    txt_file = open(txtFileName,"w+") 
    with open(pdfFileName, 'rb') as pdf_file:
        parser = PDFParser(pdf_file)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()
        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)
        txt_file.write(preprocess(output_string.getvalue()))
    txt_file.close()
    pdf_file.close()
    remove_empty_lines(txtFileName)

# %%
#Collection the Folders
folders = [x[0] for x in os.walk('/Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents')]

# %%
#Collection the PDF Docs
txtDocs=[]
for i in range(1,len(folders)):
    for d in glob.glob(folders[i]+"/*.pdf"):
        doc = pdf_to_txt(d) 
        txtDocs.append(doc)
# Out:
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/research_misconduct_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/graduate_research_degrees_joint_doctoral_degree_research_policy_v3.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/human_research_ethics_policy_v4.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/animal_ethics_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/responsible_conduct_of_research_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/honours_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/admissions_coursework_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enrolments_courseworl_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/concurrent_studies_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/honours_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/work_integrated_learning_work_placements_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_and_award_of_advanced_standing_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/unit_material_licence_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/admission_and_support_of_international_students_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_monitoring_and_progression_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_monitoring_and_progression_procedure_v3.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_appeals_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/award_of_bachelor_degrees_with_distinction_or_high_distinction_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/issuing_of_non-award_certificates_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_procedure_2016august.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/conscientious_objection_in_teaching_and_assessment_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/transnational_education_via_partnerships_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_appeals_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_progression_mandatory_interview_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/recording_grades_on_academic_transcripts_for_non-award_including_dest_enabling_course_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/masterclass_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/change_of_course_enrolment_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/work_integraed_learning_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/teaching_periods_patterns_and_academic_calendars_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_guideline_2016January01.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/change_of_course_enrolment_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/library_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_disability_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enrolments_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/timetabling_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/short_course_open_program_murdoch_executive_educationa_centre_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/service_teaching_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/unit_materials_standard.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enabling_programs_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/international_student_transfer_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/articulations_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/advanced_standing_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/coursework_regulations_effective-from_1january2018.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/maintenance_planning_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/air_conditioning_and_heating_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/copyright_policy_v3.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_collections_policy_v3.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/policy_on_the_information_literacy_program_delivered_by_the_library_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/parking_and_traffic_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/asbestos_management_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/security_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_online_licensed_resource_access_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/special_collections_policy_v1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/environmental_sustainability_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/immunisation_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/manual_handling_and_work_station_ergonomics_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/portable_amenity_furniture_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/safety_health_and_wellbeing_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/children_in_the_workplace_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/finance_purchasing_insurance/murdoch_univerisity_foundation_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/finance_purchasing_insurance/murdoch_university_veterinary_fund_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/student_experience/international_under-18_students_policy_v2.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/student_experience/suspension_cancellation_approved_leave_and_withdrawal_from_courses_procedure_v3.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/password_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/ict_security_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/it_conditions_of_use_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/email_and_electronic_messaging_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/end_user_computing_device_procurement_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/people_culture/workplace_bullying_and_harassment_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fraud_and_corruption_control_plan.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fee_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/establishment_of_undergraduate_honours_postgraduate_by_coursework_and_recruitment_scholarships_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/intellectual_property_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/award_of_honorary_degree_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/internationalisation_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/award_nomenclature_certification_and_issuance_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/conflict_of_interest_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no19_alumni.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/archives_and_archival_records_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/public_interest_disclosure_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/responsible_investment_charter.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no1.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_complaints_management_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/publishing_minutes_and_agendas_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/selection_of_chancellor_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no8_interpretation.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/staff_code_of_conduct.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/posthumous_awards_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/academic_council_statement_of_governance_principles.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/senate_statement_of_governance_principles.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/recordingkeeping_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/quality_assurance_and_improvement_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no18_intellectual_property.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_loan_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no26_student_misconduct.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/graduate_research_degrees_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/higher_doctorate_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_appeals_committee_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/college_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no21_affiliated_institutions.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/conduct_of_examinations_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/university_medals_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/complaints_management_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no4_degrees_diplomas_certificates.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/by_laws.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/animals_on_campus_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_discipline_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/authorship_attribution_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no25_vice_chancellor.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/rules_for_the_conduct_of_examinations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/senate_medal_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/privacy_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/naming_of_chairs_buildings_and_facilities_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/election_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_code_of_conduct.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/data_classification_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/academic_council_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/guild_election_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fraud_corruption_and_misconduct_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/regalia_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/dictionary_of_terms_general.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_discipline_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/code_of_ethics.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no11_admissions.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no20_examinations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no15_elections.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fee_rules.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no22_fees.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/public_interest_disclosure_procedure.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/guild_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no5_academic_council.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no17_guild_of_students.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/alumni_regulations.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/social_media_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/brand_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/de-accessioning_of_artwork_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/art_board_terms_of_reference.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/the_loadn_of_artworks_policy.txt
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/acquisition_of_artwork_policy.txt

# %%
csvFileName = '/Users/pamelapham/Documents/Murdoch/ICT302/CoreProgram/data/train_data.csv'
docNodeFileName = '/Users/pamelapham/Documents/Murdoch/ICT302/CoreProgram/data/doc_nodes.csv'

if os.path.isfile(csvFileName):
    os.remove(csvFileName)
if os.path.isfile(docNodeFileName):
    os.remove(docNodeFileName)
    
dataFile = open(csvFileName,"a+")
dataFile.write('name,category,text\n')

docNodeFile = open(docNodeFileName,"a+")
docNodeFile.write('name,category,nodesize\n')

for i in range(1,len(folders)):
    for txtDoc in glob.glob(folders[i]+"/*.txt"):
        print(txtDoc)
        with open(txtDoc, 'r') as f:
            docname=txtDoc[txtDoc.rindex('/')+1:txtDoc.rindex('.')]
            catname=folders[i][folders[i].rindex('/')+1::]
            print(docname)
            print(catname)
            text = f.readline().rstrip()
            dataFile.write(docname+','+catname+','+text+'\n')
            docNodeFile.write(docname+','+catname+','+str(len(text))+'\n')
dataFile.close()
docNodeFile.close()
# Out:
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/graduate_research_degrees_joint_doctoral_degree_research_policy_v3.txt
# graduate_research_degrees_joint_doctoral_degree_research_policy_v3
# research
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/research_misconduct_policy_v1.txt
# research_misconduct_policy_v1
# research
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/responsible_conduct_of_research_policy_v2.txt
# responsible_conduct_of_research_policy_v2
# research
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/animal_ethics_policy_v2.txt
# animal_ethics_policy_v2
# research
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/research/human_research_ethics_policy_v4.txt
# human_research_ethics_policy_v4
# research
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_procedure_2016august.txt
# assessment_procedure_2016august
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/conscientious_objection_in_teaching_and_assessment_policy.txt
# conscientious_objection_in_teaching_and_assessment_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/transnational_education_via_partnerships_policy.txt
# transnational_education_via_partnerships_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_monitoring_and_progression_procedure_v3.txt
# academic_monitoring_and_progression_procedure_v3
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/award_of_bachelor_degrees_with_distinction_or_high_distinction_policy.txt
# award_of_bachelor_degrees_with_distinction_or_high_distinction_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_appeals_policy.txt
# student_appeals_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/issuing_of_non-award_certificates_policy.txt
# issuing_of_non-award_certificates_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/work_integraed_learning_policy.txt
# work_integraed_learning_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/teaching_periods_patterns_and_academic_calendars_policy.txt
# teaching_periods_patterns_and_academic_calendars_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_appeals_procedure.txt
# student_appeals_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_progression_mandatory_interview_procedure.txt
# academic_progression_mandatory_interview_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/recording_grades_on_academic_transcripts_for_non-award_including_dest_enabling_course_policy.txt
# recording_grades_on_academic_transcripts_for_non-award_including_dest_enabling_course_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/masterclass_policy.txt
# masterclass_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/change_of_course_enrolment_procedure.txt
# change_of_course_enrolment_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enrolments_courseworl_procedure.txt
# enrolments_courseworl_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/concurrent_studies_policy.txt
# concurrent_studies_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/honours_procedure.txt
# honours_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/work_integrated_learning_work_placements_procedure.txt
# work_integrated_learning_work_placements_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_and_award_of_advanced_standing_procedure.txt
# assessment_and_award_of_advanced_standing_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/honours_policy.txt
# honours_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/admissions_coursework_policy.txt
# admissions_coursework_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/admission_and_support_of_international_students_policy.txt
# admission_and_support_of_international_students_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/academic_monitoring_and_progression_policy_v1.txt
# academic_monitoring_and_progression_policy_v1
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/unit_material_licence_policy.txt
# unit_material_licence_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/international_student_transfer_procedure.txt
# international_student_transfer_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enabling_programs_policy.txt
# enabling_programs_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/advanced_standing_policy.txt
# advanced_standing_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/coursework_regulations_effective-from_1january2018.txt
# coursework_regulations_effective-from_1january2018
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/articulations_policy.txt
# articulations_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/assessment_guideline_2016January01.txt
# assessment_guideline_2016January01
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/short_course_open_program_murdoch_executive_educationa_centre_procedure.txt
# short_course_open_program_murdoch_executive_educationa_centre_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/service_teaching_procedure.txt
# service_teaching_procedure
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/unit_materials_standard.txt
# unit_materials_standard
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/change_of_course_enrolment_policy.txt
# change_of_course_enrolment_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/student_disability_policy.txt
# student_disability_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/library_policy.txt
# library_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/enrolments_policy.txt
# enrolments_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/learning_teaching/timetabling_policy.txt
# timetabling_policy
# learning_teaching
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_policy_v1.txt
# library_policy_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/maintenance_planning_policy_v2.txt
# maintenance_planning_policy_v2
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/air_conditioning_and_heating_policy_v1.txt
# air_conditioning_and_heating_policy_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/copyright_policy_v3.txt
# copyright_policy_v3
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_collections_policy_v3.txt
# library_collections_policy_v3
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/asbestos_management_policy_v2.txt
# asbestos_management_policy_v2
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/security_policy_v2.txt
# security_policy_v2
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/library_online_licensed_resource_access_policy_v1.txt
# library_online_licensed_resource_access_policy_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/parking_and_traffic_policy_v1.txt
# parking_and_traffic_policy_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/special_collections_policy_v1.txt
# special_collections_policy_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/physical_facilities/policy_on_the_information_literacy_program_delivered_by_the_library_v1.txt
# policy_on_the_information_literacy_program_delivered_by_the_library_v1
# physical_facilities
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/manual_handling_and_work_station_ergonomics_policy.txt
# manual_handling_and_work_station_ergonomics_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/immunisation_policy.txt
# immunisation_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/environmental_sustainability_policy.txt
# environmental_sustainability_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/children_in_the_workplace_policy.txt
# children_in_the_workplace_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/portable_amenity_furniture_policy.txt
# portable_amenity_furniture_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/health_safety&environment/safety_health_and_wellbeing_policy.txt
# safety_health_and_wellbeing_policy
# health_safety&environment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/finance_purchasing_insurance/murdoch_univerisity_foundation_regulations.txt
# murdoch_univerisity_foundation_regulations
# finance_purchasing_insurance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/finance_purchasing_insurance/murdoch_university_veterinary_fund_regulations.txt
# murdoch_university_veterinary_fund_regulations
# finance_purchasing_insurance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/student_experience/international_under-18_students_policy_v2.txt
# international_under-18_students_policy_v2
# student_experience
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/student_experience/suspension_cancellation_approved_leave_and_withdrawal_from_courses_procedure_v3.txt
# suspension_cancellation_approved_leave_and_withdrawal_from_courses_procedure_v3
# student_experience
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/password_policy.txt
# password_policy
# information_technology
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/ict_security_policy.txt
# ict_security_policy
# information_technology
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/end_user_computing_device_procurement_policy.txt
# end_user_computing_device_procurement_policy
# information_technology
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/it_conditions_of_use_policy.txt
# it_conditions_of_use_policy
# information_technology
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/information_technology/email_and_electronic_messaging_policy.txt
# email_and_electronic_messaging_policy
# information_technology
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/people_culture/workplace_bullying_and_harassment_policy.txt
# workplace_bullying_and_harassment_policy
# people_culture
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/academic_council_statement_of_governance_principles.txt
# academic_council_statement_of_governance_principles
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/recordingkeeping_policy.txt
# recordingkeeping_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/senate_statement_of_governance_principles.txt
# senate_statement_of_governance_principles
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/quality_assurance_and_improvement_policy.txt
# quality_assurance_and_improvement_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/posthumous_awards_policy.txt
# posthumous_awards_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no26_student_misconduct.txt
# statute_no26_student_misconduct
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/graduate_research_degrees_regulations.txt
# graduate_research_degrees_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/higher_doctorate_regulations.txt
# higher_doctorate_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no18_intellectual_property.txt
# statute_no18_intellectual_property
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_loan_regulations.txt
# student_loan_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/award_nomenclature_certification_and_issuance_policy.txt
# award_nomenclature_certification_and_issuance_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/internationalisation_policy.txt
# internationalisation_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/conflict_of_interest_policy.txt
# conflict_of_interest_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no19_alumni.txt
# statute_no19_alumni
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/archives_and_archival_records_policy.txt
# archives_and_archival_records_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/public_interest_disclosure_policy.txt
# public_interest_disclosure_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/responsible_investment_charter.txt
# responsible_investment_charter
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fraud_and_corruption_control_plan.txt
# fraud_and_corruption_control_plan
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fee_regulations.txt
# fee_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/establishment_of_undergraduate_honours_postgraduate_by_coursework_and_recruitment_scholarships_policy.txt
# establishment_of_undergraduate_honours_postgraduate_by_coursework_and_recruitment_scholarships_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/intellectual_property_regulations.txt
# intellectual_property_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/award_of_honorary_degree_policy.txt
# award_of_honorary_degree_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/selection_of_chancellor_policy.txt
# selection_of_chancellor_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no8_interpretation.txt
# statute_no8_interpretation
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/staff_code_of_conduct.txt
# staff_code_of_conduct
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no1.txt
# statute_no1
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_complaints_management_procedure.txt
# student_complaints_management_procedure
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/publishing_minutes_and_agendas_policy.txt
# publishing_minutes_and_agendas_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/dictionary_of_terms_general.txt
# dictionary_of_terms_general
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_discipline_procedure.txt
# student_discipline_procedure
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/code_of_ethics.txt
# code_of_ethics
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no11_admissions.txt
# statute_no11_admissions
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no20_examinations.txt
# statute_no20_examinations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/academic_council_regulations.txt
# academic_council_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/guild_election_regulations.txt
# guild_election_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fraud_corruption_and_misconduct_policy.txt
# fraud_corruption_and_misconduct_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/regalia_policy.txt
# regalia_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/guild_regulations.txt
# guild_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no5_academic_council.txt
# statute_no5_academic_council
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no17_guild_of_students.txt
# statute_no17_guild_of_students
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/alumni_regulations.txt
# alumni_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no15_elections.txt
# statute_no15_elections
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/fee_rules.txt
# fee_rules
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no22_fees.txt
# statute_no22_fees
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/public_interest_disclosure_procedure.txt
# public_interest_disclosure_procedure
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/complaints_management_policy.txt
# complaints_management_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no4_degrees_diplomas_certificates.txt
# statute_no4_degrees_diplomas_certificates
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/by_laws.txt
# by_laws
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/animals_on_campus_procedure.txt
# animals_on_campus_procedure
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/college_regulations.txt
# college_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_appeals_committee_regulations.txt
# student_appeals_committee_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no21_affiliated_institutions.txt
# statute_no21_affiliated_institutions
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/conduct_of_examinations_regulations.txt
# conduct_of_examinations_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/university_medals_policy.txt
# university_medals_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/privacy_policy.txt
# privacy_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/naming_of_chairs_buildings_and_facilities_policy.txt
# naming_of_chairs_buildings_and_facilities_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_code_of_conduct.txt
# student_code_of_conduct
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/election_regulations.txt
# election_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/data_classification_policy.txt
# data_classification_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/student_discipline_regulations.txt
# student_discipline_regulations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/statute_no25_vice_chancellor.txt
# statute_no25_vice_chancellor
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/authorship_attribution_policy.txt
# authorship_attribution_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/rules_for_the_conduct_of_examinations.txt
# rules_for_the_conduct_of_examinations
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/governance/senate_medal_policy.txt
# senate_medal_policy
# governance
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/the_loadn_of_artworks_policy.txt
# the_loadn_of_artworks_policy
# CommunityDevelopment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/acquisition_of_artwork_policy.txt
# acquisition_of_artwork_policy
# CommunityDevelopment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/brand_policy.txt
# brand_policy
# CommunityDevelopment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/social_media_policy.txt
# social_media_policy
# CommunityDevelopment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/de-accessioning_of_artwork_policy.txt
# de-accessioning_of_artwork_policy
# CommunityDevelopment
# /Users/pamelapham/Documents/Murdoch/ICT302/Policy_Documents/CommunityDevelopment/art_board_terms_of_reference.txt
# art_board_terms_of_reference
# CommunityDevelopment
